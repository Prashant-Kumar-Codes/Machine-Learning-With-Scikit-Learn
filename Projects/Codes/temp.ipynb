# %%
import pandas as pd

# %%
train_df = pd.read_csv(r'D:\Codes\Artificial_Intelligence\Machine_Learning\Scikit_Learn\Projects\Datasets\flood_prediction_orginal\train.csv')

# %%
train_df.columns
# Out:
# Index(['id', 'MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
#        'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
#        'Siltation', 'AgriculturalPractices', 'Encroachments',
#        'IneffectiveDisasterPreparedness', 'DrainageSystems',
#        'CoastalVulnerability', 'Landslides', 'Watersheds',
#        'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
#        'InadequatePlanning', 'PoliticalFactors', 'FloodProbability'],
#       dtype='object')

# %%
train_df.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %%
train_df_deep = pd.read_csv(r'D:\Codes\Artificial_Intelligence\Machine_Learning\Scikit_Learn\Projects\Codes\submission_stacking.csv')

# %%
train_df_deep.head()
# Out:
#         id  FloodProbability
# 0  1117957          0.474274
# 1  1117958          0.472255
# 2  1117959          0.494960
# 3  1117960          0.527776
# 4  1117961          0.344955

# %%
print(train_df.shape)
print(train_df_deep.shape)
# Out:
# (1117957, 22)
# (745305, 2)
